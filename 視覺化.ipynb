# %%
import matplotlib.pyplot as plt

width=0.5
listx=['c','c++','c#','java','python']
listx1=[x-width/2 for x in range(len(listx))]
listx2=[x for x in range(len(listx))]
listx3=[x+width/2 for x in range(len(listx))]
listy1=[25,20,20,16,28]
listy2=[20,8,18,16,22]
listy3=[10,15,13,17,25]
plt.bar(listx1,listy1,width=0.25,label='兒童')
plt.bar(listx2,listy2,width=0.25,label='少年')
plt.bar(listx3,listy3,width=0.25,label='青年')
plt.title('資訊程式課程選修人數')
plt.xlabel('程式課程')
plt.ylabel('選修人數')
plt.legend()
plt.xticks(range(len(listx)),labels=listx)
# 設定中文字型和負號正確顯示
plt.rcParams["font.sans-serif"]="DFKai-SB" #也可設mingLiu或Microsoft JhengHei
plt.rcParams["axes.unicode_minus"]=False #解決坐標軸負數的負號顯示問題
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

size=50
listx=np.random.randint(101,size=size)
listy=np.random.randint(101,size=size)
#scale=np.random.randint(30,size=10)
#scale=scale**3

plt.xlim(0,100)
plt.ylim(0,100)
plt.scatter(listx,listy,c='r',s=50,marker='o',alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

sizes=[25,30,15,10]
labels=["北","西","南","東"]
colors=['red','green','blue','yellow']
explode=(0,0,0.2,0)
plt.pie(sizes,
       explode=explode,
       labels=labels,
       colors=colors,
       labeldistance=1.1,
       autopct="%2.1f%%",
       pctdistance=0.6,
       shadow=True,
       startangle=90)
plt.rcParams["font.sans-serif"]="DFKai-SB" #也可設mingLiu或Microsoft JhengHei
plt.rcParams["axes.unicode_minus"]=False #解決坐標軸負數的負號顯示問題
plt.show()

# %%
import matplotlib.pyplot as plt

sizes=[33.33,8.33,20.83,12.5,8.33]
labels=["Travel","Entertainment","Education","Transporation","Food"]
colors=['blue','orange','green','red','purple']
explode=(0,0.3,0,0,0)
plt.pie(sizes,
       explode=explode,
       labels=labels,
       colors=colors,
       labeldistance=1.1,
       autopct="%2.1f%%",
       pctdistance=0.6,
       shadow=True,
       startangle=320)
plt.rcParams["font.sans-serif"]="DFKai-SB" #也可設mingLiu或Microsoft JhengHei
plt.rcParams["axes.unicode_minus"]=False #解決坐標軸負數的負號顯示問題
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,2])
plt.axes([0,0,0.4,1])
plt.title('Chart 1')
plt.plot([1,2,3],'r:o')


plt.axes([0.5,0,0.4,1])
plt.title('Chart 2')
plt.plot([1,2,3],'g--o')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,4])
plt.axes([0,0,0.8,1])
plt.title('Chart 1')
plt.plot([1,2,3],'r:o')

left=(0.8-0.2)/2
down=(1-0.2)/2

plt.axes([left,down,0.2,0.2])
plt.title('Chart 2')
plt.plot([1,2,3],'g--o')
plt.show()

# %%
import matplotlib.pyplot as plt

sizes=[14,16,8,13,16,12,16,5]
labels=["商業理財","文學小說","藝術設計","人文科普","語言電腦","心靈養生","生活風格","親子共享"]
colors=['blue','orange','green','red','purple','brown','pink','gray']
explode=(0,0,0,0,0,0,0,0)
plt.pie(sizes,
       explode=explode,
       labels=labels,
       colors=colors,
       labeldistance=1.1,
       autopct="%2.1f%%",
       pctdistance=0.6,
       shadow=True,
       startangle=350)
plt.title('圖書分類銷售比率')
plt.rcParams["font.sans-serif"]="DFKai-SB" #也可設mingLiu或Microsoft JhengHei
plt.rcParams["axes.unicode_minus"]=False #解決坐標軸負數的負號顯示問題
plt.show()

# %%
import matplotlib.pyplot as plt

listx=["商業理財","文學小說","藝術設計","人文科普","語言電腦","心靈養生","生活風格","親子共享"]
listm=[0.14,0.16,0.08,0.13,0.16,0.12,0.16,0.05]
listf=[0.1,0.19,0.06,0.1,0.13,0.13,0.2,0.09]
listm=[x*100 for x in listm]
listf=[x*100 for x in listf]
plt.figure(figsize=[12,9])     
plt.rcParams["font.sans-serif"]="Microsoft JhengHei" #也可設mingLiu或Microsoft JhengHei
plt.rcParams["axes.unicode_minus"]=False #解決坐標軸負數的負號顯示問題

plt.subplot(221)
plt.title('圖書分類銷售比率-男性',fontsize=16)
plt.pie(listm,labels=listx,autopct="%2.1f%%")
plt.subplot(222)
plt.title('圖書分類銷售比率-女性',fontsize=16)
plt.pie(listm,labels=listx,autopct="%2.1f%%")

plt.subplot(223)
width=0.4
listx1=[x-width/2 for x in range(len(listx))]
listx2=[x+width/2 for x in range(len(listx))]
plt.title('圖書分類銷售比率-性別',fontsize=16)
plt.xlabel('圖書分類',fontsize=12)
plt.ylabel('銷售比率(%)',fontsize=12)
plt.bar(listx1,listm,width,label='男')
plt.bar(listx2,listf,width,label='女')
plt.xticks(range(len(listx)),listx,rotation=45)
plt.legend()

plt.subplot(224)
plt.title('圖書分類銷售比率-性別',fontsize=16)
plt.xlabel('圖書分類',fontsize=12)
plt.ylabel('銷售比率(%)',fontsize=12)
plt.plot(listx,listm,marker='s',label='男')
plt.plot(listx,listf,marker='s',label='女')
plt.gca().grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()
